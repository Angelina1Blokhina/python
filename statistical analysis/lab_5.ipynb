# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
#условные варианты
len_mid=len(mid_x)
C_x=mid_x[math.floor(len_mid/2)-1]
C_y=mid_y[math.floor(len_mid/2)-1]
u_x=[]
u_y=[]
h_x=mid_x[1]-mid_x[0]
h_y=mid_y[1]-mid_y[0]
for i in range(0, len_mid):
    u_x.append(round((mid_x[i]-C_x)/h_x))
    u_y.append(round((mid_y[i]-C_y)/h_y))
print(u)
print(C)
