# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 100

capacity = 20 
constCost = 50 
deliveryCost = 10 
maxCountPerMonth = 5
storageCost = 10 
startCount = 1
monthDemand = [0, 7, 6, 3, 0, 2] 

costs = [[100000]*(len(mounthDemand) + 1) for i in range(capacity + 1)]
costs[startCount][0] = 0
monthRes = []
wasRes = []
deliveredRes = []
takenRes = []
machinesRes = []
incCostsRes = []
storCostsRes = []
for i in range(0, len(mounthDemand)):
     for j in range(capacity + 1):
        price = costs[j][i]
        for k in range(maxCountPerMonth + 1):
            machines = j - mounthDemand[i] + k
            if 0 <= machines <=capacity:
                incomingCosts = (k * deliveryCost + constCost if k > 0 else 0)
                storageCosts = (j + k) * storageCost
                priceCount = price + incomingCosts + storageCosts
                if priceCount < costs[machines][i + 1]:
                    costs[machines][i + 1] = priceCount
                    monthRes.append(i + 1)
                    wasRes.append(j)
                    deliveredRes.append(k)
                    takenRes.append(demand[i])
                    machinesRes.append(machines)
                    incCostsRes.append(incomingCosts)
                    storCostsRes.append(storageCosts)

df = pd.DataFrame({'№ месяца': monthRes,
 'было станков (шт)': wasRes,
 'доставлено (шт)': deliveredRes,
 'забрано (шт)': takenRes,
 'осталось (шт)': machinesRes,
 'доставка (ДЕ)': incCostsRes,
 'хранение (ДЕ)': storCostsRes})
print(df)
machines = 0
for i in costs:
    print("%2d" % machines, end = ' ')
    machines += 1
    for x in i:
        print(F"%5s" % ("*" if x == 100000 else x), end = ' ')
    print()
unique = np.sort(df['№ месяца'].unique())
# Out:
#     № месяца  было станков (шт)  доставлено (шт)  забрано (шт)  осталось (шт)  \
# 0          1                  1                0             5              1
# 1          1                  1                1             5              2
# 2          1                  1                2             5              3
# 3          1                  1                3             5              4
# 4          1                  1                4             5              5
# 5          1                  1                5             5              6
# 6          2                  2                5             2              0
# 7          2                  3                5             2              1
# 8          2                  4                5             2              2
# 9          2                  5                5             2              3
# 10         2                  6                5             2              4
# 11         3                  1                5             1              0
# 12         3                  2                5             1              1
# 13         3                  3                5             1              2
# 14         3                  4                5             1              3
# 15         4                  0                3             9              0
# 16         4                  0                4             9              1
# 17         4                  0                5             9              2
# 18         4                  1                5             9              3
# 19         4                  2                5             9              4
# 20         4                  3                5             9              5
# 21         5                  0                0             9              0
# 22         5                  0                1             9              1
# 23         5                  0                2             9              2
# 24         5                  0                3             9              3
# 25         5                  0                4             9              4
# 26         5                  0                5             9              5
# 27         5                  1                0             9              1
# 28         5                  1                5             9              6
# 29         5                  2                0             9              2
# 30         5                  2                5             9              7
# 31         5                  3                5             9              8
# 32         5                  4                5             9              9
# 33         5                  5                5             9             10
# 34         6                  0                2             2              0
# 35         6                  0                3             2              1
# 36         6                  0                4             2              2
# 37         6                  0                5             2              3
# 38         6                  1                5             2              4
# 39         6                  2                0             2              0
# 40         6                  2                5             2              5
# 41         6                  3                5             2              6
# 42         6                  4                5             2              7
# 43         6                  5                5             2              8
# 44         6                  6                5             2              9
# 45         6                  7                5             2             10
# 46         6                  8                5             2             11
# 47         6                  9                5             2             12
# 48         6                 10                5             2             13
#
#     доставка (ДЕ)  хранение (ДЕ)
# 0               0             10
# 1              60             20
# 2              70             30
# 3              80             40
# 4              90             50
# 5             100             60
# 6             100             70
# 7             100             80
# 8             100             90
# 9             100            100
# 10            100            110
# 11            100             60
# 12            100             70
# 13            100             80
# 14            100             90
# 15             80             30
# 16             90             40
# 17            100             50
# 18            100             60
# 19            100             70
# 20            100             80
# 21              0              0
# 22             60             10
# 23             70             20
# 24             80             30
# 25             90             40
# 26            100             50
# 27              0             10
# 28            100             60
# 29              0             20
# 30            100             70
# 31            100             80
# 32            100             90
# 33            100            100
# 34             70             20
# 35             80             30
# 36             90             40
# 37            100             50
# 38            100             60
# 39              0             20
# 40            100             70
# 41            100             80
# 42            100             90
# 43            100            100
# 44            100            110
# 45            100            120
# 46            100            130
# 47            100            140
# 48            100            150
#  0     *     *   250   440   550   550   630
#  1     0    10   280   480   570   580   660
#  2     *    80   310   520   590   610   680
#  3     *   100   340   560   640   660   700
#  4     *   120   370     *   690   680   740
#  5     *   140     *     *   740   700   780
#  6     *   160     *     *     *   730   840
#  7     *     *     *     *     *   760   870
#  8     *     *     *     *     *   820   900
#  9     *     *     *     *     *   880   940
# 10     *     *     *     *     *   940   980
# 11     *     *     *     *     *     *  1050
# 12     *     *     *     *     *     *  1120
# 13     *     *     *     *     *     *  1190
# 14     *     *     *     *     *     *     *
# 15     *     *     *     *     *     *     *
# 16     *     *     *     *     *     *     *
# 17     *     *     *     *     *     *     *
# 18     *     *     *     *     *     *     *
# 19     *     *     *     *     *     *     *
# 20     *     *     *     *     *     *     *

# %%
costs = [[maxCost]*(len(demand) + 1) for i in range(capacity + 1)]
print(costs)
# Out:
# [[1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000], [1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]]
