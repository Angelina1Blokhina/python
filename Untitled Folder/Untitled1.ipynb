# %%
from cvxopt.modeling import variable, op

# %%
def count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20,z):         
    x_non_negative = (x >= 0) #общее условие для всех х           
    problem =op(z,[mass1,mass2,mass3,mass4 ,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, x_non_negative])
    problem.solve(solver='glpk')  
    problem.status     
    print("Максимальное количество станков -",problem.objective.value()[0])
    print(x.value)
    for i in [1,6,11,16]:
        print("| x",i, "= " ,x.value[i-1],"| x",i+1, "= " , x.value[i],"| x",i+2, "= " , x.value[i+1],"| x",i+3, "= " , x.value[i+2],"| x",i+4, "= " , x.value[i+3],"|")

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -6436.788046107449

# %% [markdown]
# Исследование 1

# %% [markdown]
# Начальный запас: 1000

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 1000)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=500)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -5001.782283057852
# [ 5.00e+02]
# [ 8.25e+02]
# [ 1.20e+03]
# [ 4.96e+02]
# [ 7.19e+02]
# [ 5.68e-14]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 1.24e+03]
# [ 0.00e+00]
# [ 5.00e+02]
# [ 6.25e+02]
# [ 6.25e+02]
# [ 6.57e+02]
# [ 7.19e+02]
# [ 0.00e+00]
# [-2.06e-14]
# [ 5.71e+02]
# [ 1.08e+03]
# [ 0.00e+00]
#
# | x 1 =  499.99999999999994 | x 2 =  824.9999999999999 | x 3 =  1196.2499999999998 | x 4 =  495.62520037760055 | x 5 =  718.6565405475208 |
# | x 6 =  5.684341886080802e-14 | x 7 =  0.0 | x 8 =  0.0 | x 9 =  1238.9372996223992 | x 10 =  0.0 |
# | x 11 =  500.0 | x 12 =  624.9999999999999 | x 13 =  625.0 | x 14 =  657.4573863636363 | x 15 =  718.6565405475208 |
# | x 16 =  0.0 | x 17 =  -2.0605739337042905e-14 | x 18 =  571.2499999999998 | x 19 =  1077.1051136363633 | x 20 =  0.0 |

# %% [markdown]
# Начальный запас: 3000

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 3000)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=1500)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -6022.867256449317
# [ 1.38e+03]
# [ 1.39e+03]
# [ 1.43e+03]
# [ 6.16e+02]
# [ 8.93e+02]
# [ 1.21e+02]
# [ 6.12e+02]
# [ 5.82e+02]
# [ 1.46e+03]
# [ 0.00e+00]
# [ 6.25e+02]
# [ 6.75e+02]
# [ 7.50e+02]
# [ 8.22e+02]
# [ 8.93e+02]
# [ 8.75e+02]
# [ 1.33e+03]
# [ 1.26e+03]
# [ 1.25e+03]
# [ 0.00e+00]

# %% [markdown]
# Начальный запас: 6500

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 6500)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=3250)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -6652.746718972559
# [ 1.38e+03]
# [ 1.51e+03]
# [ 1.54e+03]
# [ 6.86e+02]
# [ 9.95e+02]
# [ 1.87e+03]
# [ 4.92e+02]
# [ 6.45e+02]
# [ 1.55e+03]
# [ 0.00e+00]
# [ 6.25e+02]
# [ 7.74e+02]
# [ 8.44e+02]
# [ 9.20e+02]
# [ 9.95e+02]
# [ 2.62e+03]
# [ 1.23e+03]
# [ 1.34e+03]
# [ 1.32e+03]
# [ 0.00e+00]

# %% [markdown]
# Начальный запас:8500

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 8500)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=4250)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -7012.677840414413
# [ 1.38e+03]
# [ 1.58e+03]
# [ 1.61e+03]
# [ 7.26e+02]
# [ 1.05e+03]
# [ 2.87e+03]
# [ 4.23e+02]
# [ 6.81e+02]
# [ 1.60e+03]
# [ 0.00e+00]
# [ 6.25e+02]
# [ 8.31e+02]
# [ 8.97e+02]
# [ 9.76e+02]
# [ 1.05e+03]
# [ 3.62e+03]
# [ 1.17e+03]
# [ 1.39e+03]
# [ 1.35e+03]
# [ 0.00e+00]

# %% [markdown]
# Начальный запас:10000

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 10000)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1000)
mass7=(1.6*x[11]-x[15]/11<=1000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=5000)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -7282.626181495805
# [ 1.38e+03]
# [ 1.63e+03]
# [ 1.65e+03]
# [ 7.57e+02]
# [ 1.10e+03]
# [ 3.62e+03]
# [ 3.71e+02]
# [ 7.07e+02]
# [ 1.64e+03]
# [ 0.00e+00]
# [ 6.25e+02]
# [ 8.74e+02]
# [ 9.38e+02]
# [ 1.02e+03]
# [ 1.10e+03]
# [ 4.38e+03]
# [ 1.13e+03]
# [ 1.42e+03]
# [ 1.38e+03]
# [ 0.00e+00]

# %% [markdown]
# Исходная производственная мощность станкостроительного завода = 100ст/г

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 100)
mass7=(1.6*x[11]-x[15]/11<=100)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=100)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=100)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=100)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -2419.9129697353383
# [ 1.38e+03]
# [ 1.47e+03]
# [ 1.50e+03]
# [ 3.55e+02]
# [ 5.15e+02]
# [ 1.27e+03]
# [ 5.33e+02]
# [ 6.23e+02]
# [ 1.83e+03]
# [ 0.00e+00]
# [ 6.25e+01]
# [ 2.10e+02]
# [ 3.11e+02]
# [ 4.14e+02]
# [ 5.15e+02]
# [ 2.59e+03]
# [ 1.79e+03]
# [ 1.82e+03]
# [ 1.77e+03]
# [ 0.00e+00]
#
# | x 1 =  1379.3103448275863 | x 2 =  1466.9441141498214 | x 3 =  1503.7065890360411 | x 4 =  355.00614514062795 | x 5 =  514.7589104539105 |
# | x 6 =  1270.6896551724137 | x 7 =  533.0558858501786 | x 8 =  623.3623764811998 | x 9 =  1825.3684089616315 | x 10 =  0.0 |
# | x 11 =  62.5 | x 12 =  209.5170454545455 | x 13 =  311.2490315082648 | x 14 =  414.4206186678655 | x 15 =  514.7589104539105 |
# | x 16 =  2587.5 | x 17 =  1790.4829545454545 | x 18 =  1815.8199340089761 | x 19 =  1765.953935434394 | x 20 =  0.0 |

# %% [markdown]
# 700

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 700)
mass7=(1.6*x[11]-x[15]/11<=700)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=700)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=700)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=700)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -5097.829687316744
# [ 1.38e+03]
# [ 1.47e+03]
# [ 1.50e+03]
# [ 5.60e+02]
# [ 8.12e+02]
# [ 1.27e+03]
# [ 5.33e+02]
# [ 6.23e+02]
# [ 1.62e+03]
# [ 0.00e+00]
# [ 4.38e+02]
# [ 5.63e+02]
# [ 6.45e+02]
# [ 7.29e+02]
# [ 8.12e+02]
# [ 2.21e+03]
# [ 1.44e+03]
# [ 1.48e+03]
# [ 1.45e+03]
# [ 0.00e+00]
#
# | x 1 =  1379.3103448275863 | x 2 =  1466.9441141498214 | x 3 =  1503.7065890360411 | x 4 =  559.6717891585598 | x 5 =  811.5240942799117 |
# | x 6 =  1270.6896551724137 | x 7 =  533.0558858501786 | x 8 =  623.3623764811998 | x 9 =  1620.7027649436995 | x 10 =  0.0 |
# | x 11 =  437.5 | x 12 =  563.2102272727273 | x 13 =  644.8460098140497 | x 14 =  729.0632232062765 | x 15 =  811.5240942799118 |
# | x 16 =  2212.5 | x 17 =  1436.7897727272727 | x 18 =  1482.2229557031912 | x 19 =  1451.311330895983 | x 20 =  0.0 |

# %% [markdown]
# 1800

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 1800)
mass7=(1.6*x[11]-x[15]/11<=1800)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=1800)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=1800)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=1800)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -10007.343669549326
# [ 1.38e+03]
# [ 1.47e+03]
# [ 1.50e+03]
# [ 9.35e+02]
# [ 1.36e+03]
# [ 1.27e+03]
# [ 5.33e+02]
# [ 6.23e+02]
# [ 1.25e+03]
# [ 0.00e+00]
# [ 1.12e+03]
# [ 1.21e+03]
# [ 1.26e+03]
# [ 1.31e+03]
# [ 1.36e+03]
# [ 1.52e+03]
# [ 7.88e+02]
# [ 8.71e+02]
# [ 8.74e+02]
# [ 0.00e+00]
#
# | x 1 =  1379.3103448275863 | x 2 =  1466.9441141498214 | x 3 =  1503.7065890360411 | x 4 =  934.8921365247684 | x 5 =  1355.5935979609142 |
# | x 6 =  1270.6896551724137 | x 7 =  533.0558858501786 | x 8 =  623.3623764811998 | x 9 =  1245.482417577491 | x 10 =  0.0 |
# | x 11 =  1125.0 | x 12 =  1211.6477272727273 | x 13 =  1256.4404700413227 | x 14 =  1305.9079981933633 | x 15 =  1355.5935979609142 |
# | x 16 =  1525.0 | x 17 =  788.3522727272727 | x 18 =  870.6284954759183 | x 19 =  874.4665559088962 | x 20 =  0.0 |

# %% [markdown]
# 3000

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 3000)
mass7=(1.6*x[11]-x[15]/11<=3000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=3000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=3000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=3000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -15363.177104712136
# [ 1.38e+03]
# [ 1.47e+03]
# [ 1.50e+03]
# [ 1.34e+03]
# [ 1.60e+03]
# [ 1.27e+03]
# [ 5.33e+02]
# [ 6.23e+02]
# [ 8.36e+02]
# [ 3.45e+02]
# [ 1.88e+03]
# [ 1.92e+03]
# [ 1.92e+03]
# [ 1.94e+03]
# [ 1.95e+03]
# [ 7.75e+02]
# [ 8.10e+01]
# [ 2.03e+02]
# [ 2.45e+02]
# [ 0.00e+00]
#
# | x 1 =  1379.3103448275863 | x 2 =  1466.9441141498214 | x 3 =  1503.7065890360407 | x 4 =  1344.223424560632 | x 5 =  1604.3626928996841 |
# | x 6 =  1270.6896551724137 | x 7 =  533.0558858501786 | x 8 =  623.3623764812 | x 9 =  836.1511295416271 | x 10 =  344.7612727132325 |
# | x 11 =  1875.0 | x 12 =  1919.034090909091 | x 13 =  1923.6344266528927 | x 14 =  1935.193207270185 | x 15 =  1949.1239656129164 |
# | x 16 =  775.0 | x 17 =  80.96590909090908 | x 18 =  203.43453886434835 | x 19 =  245.1813468320741 | x 20 =  0.0 |

# %% [markdown]
# 5000

# %%
x = variable(20, 'x')
z=(1.6*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 5300)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.9*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.9*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.9*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.9*x[3] == 0)

mass6 = (1.6*x[10] <= 5000)
mass7=(1.6*x[11]-x[15]/11<=5000)
mass8=(1.6*x[12]-(x[15]+x[16])/11<=5000)
mass9=(1.6*x[13]-(x[15]+x[16]+x[17])/11<=5000)
mass10=(1.6*x[14]-(x[15]+x[16]+x[17]+x[18])/11<=5000)

mass11=(2.9*x[0] <= 4000)
mass12=(2.9*x[1]-0.2*x[5] <= 4000)
mass13=(2.9*x[2]-0.2*(x[5]+x[6]) <= 4000)
mass14=(2.9*x[3]-0.2*(x[5]+x[6]+x[7]) <= 4000)
mass15=(2.9*x[4]-0.2*(x[5]+x[6]+x[7]+x[8]) <= 4000)

mass16=(x[10]+x[15]<=2650)
mass17=(2*(x[11]+x[16])-2.9*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.9*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.9*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.9*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальное количество станков - -17920.246898191806
# [ 1.38e+03]
# [ 1.47e+03]
# [ 1.50e+03]
# [ 1.55e+03]
# [ 1.59e+03]
# [ 1.27e+03]
# [ 5.33e+02]
# [ 6.23e+02]
# [ 6.34e+02]
# [ 6.52e+02]
# [ 2.65e+03]
# [ 2.00e+03]
# [ 2.13e+03]
# [ 2.18e+03]
# [ 2.24e+03]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
#
# | x 1 =  1379.3103448275863 | x 2 =  1466.9441141498214 | x 3 =  1503.7065890360411 | x 4 =  1546.6970977588821 | x 5 =  1590.3989912998047 |
# | x 6 =  1270.6896551724137 | x 7 =  533.0558858501787 | x 8 =  623.3623764812 | x 9 =  633.6774563433773 | x 10 =  652.3118004505741 |
# | x 11 =  2650.0 | x 12 =  2000.0 | x 13 =  2127.068965517241 | x 14 =  2180.3745541022595 | x 15 =  2242.710791750379 |
# | x 16 =  0.0 | x 17 =  0.0 | x 18 =  0.0 | x 19 =  0.0 | x 20 =  0.0 |

# %%
x = variable(20, 'x')
z=(1.2*(-x[10] -x[11] -x[12]-x[13]-x[14]))
mass1 = (x[0]+x[5]+x[10]+x[15] == 3800)
mass2 = (x[1] + x[6]+x[11]+x[16] -2.5*x[0] == 0)
mass3 = (x[2] + x[7]+x[12]+x[17] -2.5*x[1] == 0)
mass4 = (x[3] + x[8]+x[13]+x[18] -2.5*x[2] == 0)
mass5 = (x[4] + x[9]+x[14]+x[19] -2.5*x[3] == 0)

mass6 = (1.2*x[10] <= 1800)
mass7=(1.2*x[11]-x[15]/12<=1800)
mass8=(1.2*x[12]-(x[15]+x[16])/12<=1800)
mass9=(1.2*x[13]-(x[15]+x[16]+x[17])/12<=1800)
mass10=(1.2*x[14]-(x[15]+x[16]+x[17]+x[18])/12<=1800)

mass11=(2.5*x[0] <= 4100)
mass12=(2.5*x[1]-0.3*x[5] <= 4100)
mass13=(2.5*x[2]-0.3*(x[5]+x[6]) <= 4100)
mass14=(2.5*x[3]-0.3*(x[5]+x[6]+x[7]) <= 4100)
mass15=(2.5*x[4]-0.3*(x[5]+x[6]+x[7]+x[8]) <= 4100)

mass16=(x[10]+x[15]<=1900)
mass17=(2*(x[11]+x[16])-2.5*x[0]<=0)
mass18=(2*(x[12]+x[17])-2.5*x[1]<=0)
mass19=(2*(x[13]+x[18])-2.5*x[2]<=0)
mass20=(2*(x[14]+x[19])-2.5*x[3]<=0)


count(mass1, mass2, mass3, mass4,mass5,mass6,mass7,mass8,mass9,mass10,mass11,mass12, mass13, mass14, mass15, mass16, mass17, mass18, mass19,mass20, z)
# Out:
# Максимальная стоимость закупки - -9396.825142032463
# Матрица закупок:
# | x 1 =  1640.0 | x 2 =  1671.2 | x 3 =  1716.6559999999997 | x 4 =  1310.6944705456485 |
# | x 5 =  1638.3680881820608 | x 6 =  260.0 | x 7 =  378.79999999999995 | x 8 =  372.34400000000016 |
# | x 9 =  835.1255294543514 | x 10 =  0.0 | x 11 =  1500.0 | x 12 =  1527.7777777777778 |
# | x 14 =  1600.4985425240052 | x 15 =  1638.3680881820605 | x 16 =  400.0 | x 17 =  522.2222222222222 |
